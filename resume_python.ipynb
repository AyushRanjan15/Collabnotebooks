# %%
# Text Variables
Header = "made using python <refer to portfolio for code>"
Name = 'AYUSH RANJAN'
Title = 'Data Science & Analytics'
Contact = 'Melbourne, VIC\n0402484302\n ayushranjan15@gmail.com \n https://www.linkedin.com/in/ayush-ranjan-582b9a136/ \nhttps://github.com/AyushRanjan15'

ProfessionalSummary = "Data Analyst with experience in working on all stages of data science \nproject cycle i.e. defining problems, cleaning data, selecting comparison \nmatrix for models, testing different model and presenting insights to \nstakeholders. An inquisitive and collaborative nature with a lucid \napproach towards problems."

ProjectsHeader = 'PROJECTS/PUBLICATIONS'
ProjectOneTitle = 'Ames House Price prediction'
ProjectOneDesc = '- Kaggle competion kernal\n- Trained and compared different regression models to find with lowest error \n- EDA \n - Feature Engineering'

ProjectTwoTitle = 'Star Wars Data Cleaning'
ProjectTwoDesc = '- Cleaned and combined several tables using pandas library in Python'

ProjectThreeTitle = 'Is COVID - 19 Racist'
ProjectThreeDesc = '- Data Journalism \n- Combined and Cleaned data from public data sources\n- Used pandas and matplotlib to explore a story on \n how COVID-19 is effecting minorities'

Portfolio = 'Portfolio: https://ayushranjan15.github.io'

WorkHeader = 'EXPERIENCE'

WorkOneTitle = 'Analytics Consultant - Redwood Algorithms'
WorkOneTime = 'June 2018 to August 2018'
WorkOneDesc = '- Defining problem statement as described by stakeholders\n- Gathering and cleaning data\n- Testing models\n- Communicating results'

WorkTwoTitle = 'Intern - Dia capital advisory'
WorkTwoTime = 'February 2018 to May 2018'
WorkTwoDesc = '- Maintain Database\n- Operations'

EduHeader = 'EDUCATION'

EduOneTitle = 'Masters of Data Science\n RMIT University'
EduOneTime = '2019 - Present'
EduOneDesc = '- Major: Management, Minor: Statistics'

EduTwoTitle = 'Bachelors of Technology - Electronics & Communication\n Manipal University Jaipur'
EduTwoTime = '2014-2018'

SkillsHeader = 'Skills'
SkillsDesc = '- R\n- Python\n- Pandas\n- NumPy\n- Data Visualization\n- Data Cleaning\n- Command Line\n- Git and Version Control\n- SQL\n- APIs\n- Probability/Statistics\n- Data Journalism\n- Tensor Flow'
# ExtrasTitle = 'DataQuest\nData Scientist Path'
# ExtrasDesc = 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis'
# CodeTitle = 'View Portfolio'
# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline
# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(8.5, 11))
# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)
# set background color
ax.set_facecolor('white')
# remove axes
plt.axis('off')
# add text
plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.75)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')


plt.annotate('PROFESSIONAL SUMMARY', (.02,.86), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProfessionalSummary, (.02,.75), weight='regular', fontsize=10)

plt.annotate(ProjectsHeader, (.02,.70), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.02,.675), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.04,.60), weight='regular', fontsize=9)

plt.annotate(ProjectTwoTitle, (.02,.575), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.55), weight='regular', fontsize=9)

plt.annotate(ProjectThreeTitle, (.02,.525), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.04,.45), weight='regular', fontsize=9)

####################################

plt.annotate(Portfolio, (.02,.88), weight='bold', fontsize=10)

plt.annotate(WorkHeader, (.02,.425), weight='bold', fontsize=10, color='#58C1B2')

plt.annotate(WorkOneTitle, (.02,.40), weight='bold', fontsize=10)
plt.annotate(WorkOneTime, (.02,.385), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkOneDesc, (.04,.320), weight='regular', fontsize=9)

plt.annotate(WorkTwoTitle, (.02,.30), weight='bold', fontsize=10)
plt.annotate(WorkTwoTime, (.02,.285), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkTwoDesc, (.04,.25), weight='regular', fontsize=9)

# plt.annotate(WorkThreeTitle, (.02,.295), weight='bold', fontsize=10)
# plt.annotate(WorkThreeTime, (.02,.28), weight='regular', fontsize=9, alpha=.6)
# plt.annotate(WorkThreeDesc, (.04,.247), weight='regular', fontsize=9)

plt.annotate(EduHeader, (.02,.225), weight='bold', fontsize=10, color='#58C1B2')

plt.annotate(EduOneTitle, (.02,.1825), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.17), weight='regular', fontsize=9, alpha=.6)
# plt.annotate(EduOneDesc, (.04,.245), weight='regular', fontsize=9)

plt.annotate(EduTwoTitle, (.02,.13), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.115), weight='regular', fontsize=9, alpha=.6)

plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.56), weight='regular', fontsize=10, color='#ffffff')
# plt.annotate(ExtrasTitle, (.7,.43), weight='bold', fontsize=10, color='#ffffff')
# plt.annotate(ExtrasDesc, (.7,.345), weight='regular', fontsize=10, color='#ffffff')
# plt.annotate(CodeTitle, (.7,.2), weight='bold', fontsize=10, color='#ffffff')
#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
# arr_code = mpimg.imread('ekresumecode.png')
# imagebox = OffsetImage(arr_code, zoom=0.5)
# ab = AnnotationBbox(imagebox, (0.84, 0.12))
# ax.add_artist(ab)
plt.savefig('resumeexample.png', dpi=300, bbox_inches='tight')
